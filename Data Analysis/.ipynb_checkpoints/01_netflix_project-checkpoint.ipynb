# %% [markdown]
# ### Netflix 분석
#
# - Process
#
#
# - 1. flixpatrol 사이트에서 데이터 수집
#     - https://flixpatrol.com/top10/netflix/world/2021/full/#netflix-1
#
#
# - 2. kaggle에서 netflix 컨텐츠 데이터 수집
#     - https://www.kaggle.com/shivamb/netflix-shows
#
# - 3. netflix original 데이터 수집
#     -  https://www.netflix.com/kr/browse/genre/839338

# %% [markdown]
# #### 1. flixpatrol 사이트에서 데이터 수집

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from matplotlib import rc
import missingno as msno
import warnings
warnings.filterwarnings(action='ignore')
import time 
from tqdm import trange, notebook 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
url = "https://flixpatrol.com/top10/netflix/world/2021/full/"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
dom = BeautifulSoup(response.text,'html.parser')

# %%
elements = dom.select("#netflix-1 > div.-mx-content > div > div > table > tbody > tr")

# %%
elements[0]
# Out:
# <tr class="table-group">
# <td class="table-td w-12 font-semibold text-right text-gray-500 table-hover:text-gray-400">1.</td>
# <td class="table-td w-10">
# <span class="inline-block align-bottom w-6 h-6 rounded-full text-blue-100 bg-blue-600 text-xxs leading-6 text-center">n/a</span>
# </td>
# <td class="table-td">
# <a class="hover:underline" href="/title/red-notice/">Red Notice</a>
# <span class="inline-block align-baseline w-3 h-3" title="This title is Netflix original">
# <svg viewbox="0 0 512 512"><path d="M304 0h96v512h-96zM112 0h96v512h-96z" fill="#b20710"></path><path d="M400 512h-96L112 0h96z" fill="#e50914"></path></svg>
# </span> </td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">25,918</td>
# <td class="table-td w-18 text-right text-gray-500 table-hover:text-gray-400">–</td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">90</td>
# <td class="table-td w-16 text-right text-gray-500 table-hover:text-gray-400">288</td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">48</td>
# <td class="table-td w-16 text-right text-gray-500 table-hover:text-gray-400">540</td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">25,918</td>
# </tr>

# %%
#link = "https://flixpatrol.com" + element.select_one("a").get("href")

# %%
def connect(link,headers):
    response = requests.get(link,headers=headers)
    dom = BeautifulSoup(response.text,'html.parser')
    return dom

# %%
from fake_useragent import UserAgent

ua = UserAgent()
# Out:
# Collecting fake_useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Building wheels for collected packages: fake-useragent
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13486 sha256=acb31227a345353cfc3e418d1a7ee79bf05994e7ec865b47ba5b3538799a7fac
#   Stored in directory: /Users/chominhee/Library/Caches/pip/wheels/a0/b8/b7/8c942b2c5be5158b874a88195116b05ad124bac795f6665e65
# Successfully built fake-useragent
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-0.1.11
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "/Users/chominhee/opt/anaconda3/lib/python3.8/site-packages/fake_useragent/utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "/Users/chominhee/opt/anaconda3/lib/python3.8/site-packages/fake_useragent/utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range

# %%
movie = []
for element in notebook.tqdm(elements):
    name = element.select_one("a").text
    link = "https://flixpatrol.com" + element.select_one("a").get("href")
    points = element.select("td:nth-child(4)")[0].text
    countries = element.select("td:nth-child(6)")[0].text
    days = element.select("td:nth-child(8)")[0].text
    time.sleep(1)
    headers = {'User-Agent' : ua.random}
    dom = connect(link,headers)
    #detail = dom.select_one("body > div.content.mt-4 > div > div.flex-grow > div.mb-6 > div.flex.flex-wrap.text-gray-500 > div")
    rating = dom.select_one(" body > div.content.mt-4 > div > div.flex-grow > div.lg\:flex.lg\:space-x-8.justify-between > div:nth-child(1) > div.flex.flex-wrap.justify-around.text-center > div.px-2.py-4.w-32 > div.mb-1.text-2xl.text-gray-400").text
    time.sleep(1)
    dom2 = connect(link+"top10/",headers)
    popular_c = dom2.select_one("#toc-netflix-1 > div:nth-child(2) > table > tbody > tr:nth-child(1) > td.table-td.w-2\/5 > a").text
    movie.append({"name":name,
                      "points": points,
                      "countries":countries,
                      "days":days,
                 "rating":rating,
                 "popular_country":popular_c})

movie_df = pd.DataFrame(movie)
movie_df.head(30)
# Out:
#   0%|          | 0/176 [00:00<?, ?it/s]
#                                      name  points countries days  rating  \
# 0                              Red Notice  25,918        90   48  6.5/10
# 1                        We Can Be Heroes  25,311        82  214  4.9/10
# 2                        Army of the Dead  18,888        89   92  6.3/10
# 3                             Wish Dragon  16,953        82   88       –
# 4                         Army of Thieves  15,081        90   52  6.4/10
# 5          The Mitchells vs. The Machines  14,902        82   74  8.4/10
# 6                              Fatherhood  14,660        82   54  6.8/10
# 7                        The Unforgivable  13,458        89   20  7.2/10
# 8                              The Guilty  12,930        83   43  6.3/10
# 9                                 Yes Day  12,809        81   66       –
# 10                              Love Hard  11,782        90   50       –
# 11                       Outside the Wire  11,661        82   45  5.3/10
# 12                      Love and Monsters  11,582        81   33  7.0/10
# 13                                   Kate  11,224        83   50  6.3/10
# 14                                   Vivo  11,037        79   58  6.8/10
# 15                                Minions  10,972        78  132  6.4/10
# 16                    Back to the Outback  10,555        88   20  6.7/10
# 17                          He's All That  10,222        83   35  4.4/10
# 18                             Sweet Girl  10,051        82   32  5.5/10
# 19                          Blood Red Sky   9,757        82   31  6.0/10
# 20              Major Grom: Plague Doctor   9,642        80   98  6.4/10
# 21       My Little Pony: A New Generation   9,615        81   41  7.3/10
# 22                   The Forgotten Battle   9,321        83   24  7.2/10
# 23                    The Kissing Booth 3   9,219        82   28  5.1/10
# 24    To All the Boys: Always and Forever   9,058        83   24  6.5/10
# 25  Fast & Furious Presents: Hobbs & Shaw   8,994        73  257  6.0/10
# 26                          Thunder Force   8,842        82   35  4.2/10
# 27                           I Care a Lot   8,610        54   41  6.4/10
# 28                The Woman in the Window   8,547        82   33  5.8/10
# 29                               365 Days   8,488        60  313  3.5/10
#
#    popular_country
# 0        Argentina
# 1        Argentina
# 2        Argentina
# 3        Argentina
# 4        Argentina
# 5        Argentina
# 6        Argentina
# 7        Argentina
# 8        Argentina
# 9        Argentina
# 10       Argentina
# 11       Argentina
# 12       Argentina
# 13       Argentina
# 14       Argentina
# 15       Argentina
# 16       Argentina
# 17       Argentina
# 18       Argentina
# 19       Argentina
# 20       Argentina
# 21       Argentina
# 22       Argentina
# 23       Argentina
# 24       Argentina
# 25       Argentina
# 26       Argentina
# 27       Argentina
# 28       Argentina
# 29           India

# %%
movie_df.shape
# Out:
# (176, 6)

# %%
movie_df.tail(30)
# Out:
#                                                   name points countries days  \
# 146                                        Tower Heist  2,458        41   39
# 147                                           47 Ronin  2,458        54   29
# 148                                            Monster  2,453        65   10
# 149                                     Mortal Engines  2,339        45   83
# 150                                              Ted 2  2,335        48   26
# 151                                           R.I.P.D.  2,325        39   19
# 152                                        A Week Away  2,314        76   13
# 153                           This Little Love of Mine  2,314        58   19
# 154                        Men in Black: International  2,309        28  104
# 155                                    The Emoji Movie  2,208        26  106
# 156  Operation Varsity Blues: The College Admission...  2,179        53   15
# 157                                      Madame Claude  2,179        60   25
# 158                                The Yin Yang Master  2,161        51   27
# 159            The Adventures of Sharkboy and Lavagirl  2,075        25   75
# 160                    Rurouni Kenshin Part I: Origins  2,059        56   47
# 161                              Sniper: Ultimate Kill  2,055        34   77
# 162                                   Angel Has Fallen  2,024        17   65
# 163                                           Twilight  1,987        27   72
# 164          The Twilight Saga: Breaking Dawn - Part 2  1,945        27   66
# 165                                            Aquaman  1,940        14   95
# 166                                               Room  1,922        22   20
# 167                                          I See You  1,889        18   15
# 168                                               2012  1,886        31   51
# 169                                             Wanted  1,878        32   20
# 170                                       Just Say Yes  1,878        43   16
# 171                                             Scoob!    202         1   28
# 172                                 The Son of Bigfoot    192         7    8
# 173                                                Ava    186         4   29
# 174                                          Bombshell    181         2   14
# 175                                     Man on a Ledge    174         4   13
#
#      rating popular_country
# 146  6.2/10          Canada
# 147  6.3/10       Australia
# 148  6.3/10       Argentina
# 149  6.4/10       Argentina
# 150  6.5/10       Australia
# 151  5.6/10       Australia
# 152  5.3/10       Australia
# 153       –       Australia
# 154  5.6/10       Australia
# 155  1.4/10       Argentina
# 156  7.1/10       Australia
# 157       –       Argentina
# 158  5.8/10       Hong-Kong
# 159  3.5/10       Australia
# 160       –       Hong-Kong
# 161  5.6/10         Austria
# 162  6.4/10       Australia
# 163  5.2/10       Argentina
# 164  5.6/10       Argentina
# 165  7.7/10         Belgium
# 166  8.2/10       Argentina
# 167  6.7/10       Argentina
# 168  5.8/10          Brazil
# 169  6.7/10         Austria
# 170  4.4/10       Argentina
# 171  5.7/10       Australia
# 172  6.1/10          France
# 173  5.8/10       Argentina
# 174  6.8/10         Romania
# 175  6.6/10          Poland

# %% [markdown]
# #### 2. kaggle에서 netflix 컨텐츠 데이터 수집

# %%
net = pd.read_csv("netflix_titles.csv")

# %%
net.shape
# Out:
# (8807, 12)

# %%
net.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
ratings_ages = {'TV-PG': 'Older Kids', 'TV-MA': 'Adults', 'TV-Y7-FV': 'Older Kids',
                'TV-Y7': 'Older Kids', 'TV-14': 'Teens', 'R': 'Adults', 'TV-Y': 'Kids',
                'NR': 'Adults', 'PG-13': 'Teens', 'TV-G': 'Kids', 'PG': 'Older Kids',
                'G': 'Kids', 'UR': 'Adults', 'NC-17': 'Adults'}
net["rating"] = net["rating"].map(ratings_ages)

# %%
net["rating"].head()
# Out:
# 0     Teens
# 1    Adults
# 2    Adults
# 3    Adults
# 4    Adults
# Name: rating, dtype: object

# %%
net.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8800 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# 3. 넷플릭스 오리지널 데이터 수집

# %%
url = "https://www.netflix.com/kr/browse/genre/839338"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
dom = BeautifulSoup(response.text,'html.parser')

# %%
elements = dom.select_one("#appMountPoint > div > div.nm-collections-page > main >section>.nm-content-horizontal-row")

# %%
movies = elements.select("a")

# %%
netflix_original = []
for movie in  notebook.tqdm(movies):
    link = movie.get("href")
    response_detail = requests.get(link)
    dom2 = BeautifulSoup(response_detail.text,'html.parser')
    detail1 = dom2.select_one("#section-hero > div.hero-container > div.info-container > div.details-container > div > div.title-info-metadata-wrapper")
    year = detail1.select_one("span").text
    maturity_number= detail1.select_one(".maturity-number").text
    if detail1.select_one("a") is not None:
        main_genre = detail1.select_one("a").text
    netflix_original.append({"name":movie.select_one(".nm-collections-title-name").text,
                      "year": year,
                      "maturity_number":maturity_number,
                      "main_genre":main_genre})

net_original = pd.DataFrame(netflix_original)
net_original.head(30)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]
#                 name  year maturity_number   main_genre
# 0          지금 우리 학교는  2022             청불        호러 시리즈
# 1             오징어 게임  2021             청불        한국 드라마
# 2               D.P.  2021            15+        한국 드라마
# 3              마이 네임  2021             청불        한국 드라마
# 4             애나 만들기  2022             청불    미국 TV 프로그램
# 5            빨간 머리 앤  2017            12+       청소년 시리즈
# 6         로스트 인 스페이스  2018            12+    미국 TV 프로그램
# 7            기묘한 이야기  2016            15+        호러 시리즈
# 8                 킹덤  2019             청불        정치 시리즈
# 9               브리저튼  2020             청불           시대물
# 10             종이의 집  2017             청불       스릴러 시리즈
# 11       에밀리, 파리에 가다  2020            15+      로맨틱한 드라마
# 12             지정생존자  2016            15+        정치 시리즈
# 13                위쳐  2019             청불       판타지 시리즈
# 14            겨우, 서른  2020            15+           드라마
# 15            금붕어 아내  2022             청불      로맨틱한 드라마
# 16               루시퍼  2016             청불       판타지 시리즈
# 17              솔로지옥  2021            15+      리얼리티 시리즈
# 18            컵헤드 쇼!  2022          전체관람가        키즈 시리즈
# 19                지옥  2021             청불        호러 시리즈
# 20             더블 타겟  2016            15+     도서 원작 시리즈
# 21  쥬라기 월드: 백악기 어드벤처  2020            12+        키즈 시리즈
# 22       오티스의 비밀 상담소  2019             청불       청소년 시리즈
# 23             퀸스 갬빗  2020             청불     도서 원작 시리즈
# 24          일곱 개의 대죄  2014            15+   SF & 판타지 애니
# 25           너의 모든 것  2018             청불     도서 원작 시리즈
# 26              절대쌍교  2020            15+       판타지 시리즈
# 27              천성장가  2018            15+           시대물
# 28              스위트홈  2020             청불       판타지 시리즈
# 29             더 크라운  2016            15+        정치 시리즈

# %% [markdown]
# #### EDA의 수행 절차
# - 데이터 수집
# - 결측 데이터의 처리
# - 데이터 탐색
#     - 수집한 데이터에서 자유롭게 주제를 선정하여 데이터 분석을 통한 인사이트 도출
#     - 예시 : 인도영화는 다른 국가보다 러닝타임이 길것이다. 컨텐츠의 퀄리티가 가장 좋은 국가는?

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8800 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
net.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
msno.matrix(df=net.iloc[:,:],figsize = (8,8),color = (0.8,0.5,0.2))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df=net.iloc[:,:],figsize = (8,8),color = (0.8,0.5,0.2))
# Out:
# <AxesSubplot:>

# %%
(net_original['main_genre'].value_counts(normalize=True)*100).plot.bar(figsize = (10,13),color=sns.color_palette('cool'))
# Out:
# <AxesSubplot:>

# %%
(net_original['year'].value_counts(normalize=True)*100).plot.bar(figsize = (10,13),color=sns.color_palette('cool'))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 컨텐츠 타입과 컨텐츠 등급별 컨텐츠의 비율

# %%
# 아래의 코드는 EDA의 예시를 보여주는 것으로 실제 코드가 동작되지 않습니다.

plt.figure(figsize=(20, 5))

plt.subplot(121)
plt.title("Movie")
plt.pie(movie_count.values, labels=movie_count.index, autopct="%1.1f%%")

plt.subplot(122)
plt.title("TV Show")
plt.pie(tv_count.values, labels=tv_count.index, autopct="%1.1f%%")

plt.show()

# %% [markdown]
# 결론 : 영화가 TV쇼 보다 청소년 관람불가 등급의 비율이 더 높고 TV가 영화보다 청소년관람등급의 컨텐츠의 비율이 더 높습니다.
